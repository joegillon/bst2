# %%
import os
os.chdir('c:/bench/bst/data')
import pandas as pd

# %%
dems=pd.read_csv('mi/sos/Democrats.csv')
dems.head()
# Out:
# C:\Python39\lib\site-packages\IPython\core\interactiveshell.py:3169: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       VOTERID  DLCOUNTYCODE  JURISDCODE      AV      LASTNAME FIRSTNAME  \
# 0     6820491             1        1040      AV      ANDERSON      DALE
# 1     6820649             1        1040  NON-AV  ANUSZKIEWICZ     DAVID
# 2  4001066699             1        1040  NON-AV       BANDLOW     CAROL
# 3    31271470             1        1040  NON-AV        BECKTA      ADAM
# 4    31271471             1        1040  NON-AV        BECKTA  MADELINE
#
#   MIDDLENAME SUFFIX  RESZIPCODE      RESADDRESS1           RESADDRESS2  \
# 0    FRANCIS    NaN       48742   4306 N MOLE RD      LINCOLN MI 48742
# 1      JAMES    NaN       48721  4949 LALONDE RD  BLACK RIVER MI 48721
# 2        ANN    NaN       48742   4350 N WOOD RD      LINCOLN MI 48742
# ...

# %%
vdf=pd.read_csv('voters/Bruce_St_voters.csv')
vdf.head()
# Out:
#   last_name first_name middle_name name_suffix  birth_year gender  \
# 0     RABLE    ZACHARY      ANDREW         NaN        1988      M
# 1     BIGGS       CURT       ELLIS         NaN        1965      M
# 2     FLYNN     DENISE           M         NaN        1957      F
# 3  KIRCHNER     AUDREY         NaN         NaN        1945      F
# 4     MAZUR       LORI        ANNE         NaN        1959      F
#
#        street_address       city  zipcode  county  ...  2011-09-13  \
# 0  2015  MILLER AVE    ANN ARBOR    48103      81  ...           N
# 1  1877  MILLER AVE    ANN ARBOR    48103      81  ...           N
# 2  2133  MILLER AVE    ANN ARBOR    48103      81  ...           N
# 3  2011  MILLER AVE    ANN ARBOR    48103      81  ...           N
# 4  2035  MILLER AVE    ANN ARBOR    48103      81  ...           N
#
#    2011-08-02  2011-05-03  2011-02-22  2010-11-02  2010-09-14  2010-08-03  \
# 0           N           N           N           Y           X           X
# ...

# %%
bruce_dems=dems[dems.VOTERID.isin(vdf.voter_id)]
bruce_dems.head()
# Out:
#            VOTERID  DLCOUNTYCODE  JURISDCODE      AV     LASTNAME FIRSTNAME  \
# 862608  4001745657            81        3000  NON-AV        ADAMS    ROBERT
# 862641   102386696            81        3000  NON-AV       ADISKA    DONALD
# 863529   102957129            81        3000  NON-AV  BADALAMENTI   VINCENT
# 864302  4000863926            81        3000  NON-AV      BENNETT    GEORGE
# 864320  4000863932            81        3000  NON-AV      BENNETT     TRACY
#
#        MIDDLENAME SUFFIX  RESZIPCODE        RESADDRESS1         RESADDRESS2  \
# 862608      JAMES    NaN       48103   827 WESTWOOD AVE  ANN ARBOR MI 48103
# 862641       GARY    NaN       48103    1901 SUNRISE ST  ANN ARBOR MI 48103
# 863529     WALTER    NaN       48103  1068 WESTAIRE WAY  ANN ARBOR MI 48103
# 864302   FRANKLIN     JR       48103    1801 SUNRISE ST  ANN ARBOR MI 48103
# 864320      GAYLE    NaN       48103    1801 SUNRISE ST  ANN ARBOR MI 48103
#
# ...

# %%
len(bruce_dems)
# Out:
# 99

# %%
vdf.voter_id.dtypes
# Out:
# dtype('int64')

# %%
bruce_dems.VOTERID.dtypes
# Out:
# dtype('int64')

# %%
pd.unique(vdf.party)
# Out:
# array(['X'], dtype=object)

# %%
vdf.party='X'

# %%
for id in bruce_dems.VOTERID:
    vdf.loc[vdf.voter_id == id, 'party'] = 'D'
pd.unique(vdf.party)
# Out:
# array(['X', 'D'], dtype=object)

# %%
reps=pd.read_csv('mi/sos/Republicans.csv')
reps.head()
# Out:
# C:\Python39\lib\site-packages\IPython\core\interactiveshell.py:3169: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       VOTERID  DLCOUNTYCODE  JURISDCODE      AV LASTNAME FIRSTNAME MIDDLENAME  \
# 0  1870002909             1        1040  NON-AV     BAIR    JANINE        KAY
# 1  4003177315             1        1040  NON-AV     BAIR    STEVEN      BURNS
# 2  1870003525             1        1040  NON-AV     BAIR  VICTORIA     JANINE
# 3   106452127             1        1040  NON-AV  BARBATO     KELLY        ANN
# 4   107644463             1        1040  NON-AV  BARBATO    ROBERT       CARL
#
#   SUFFIX  RESZIPCODE          RESADDRESS1           RESADDRESS2 MAILADDRESS1  \
# 0    NaN       48721        5896 RIDGE RD  BLACK RIVER MI 48721          NaN
# 1    NaN       48721        5896 RIDGE RD  BLACK RIVER MI 48721          NaN
# ...

# %%
bruce_reps=reps[reps.VOTERID.isin(vdf.voter_id)]
bruce_reps.head()
# Out:
#             VOTERID  DLCOUNTYCODE  JURISDCODE      AV  LASTNAME  FIRSTNAME  \
# 1156230  1630000341            81        3000      AV    BEHNKE    DOROTHY
# 1156895     4465303            81        3000  NON-AV  CHASTEEN    MARILYN
# 1156940  1630000927            81        3000  NON-AV  CHRISTEN  CATHERINE
# 1157122  1630001644            81        3000  NON-AV     COWAN          A
# 1157124     4484232            81        3000  NON-AV     COWAN      HEIDI
#
#         MIDDLENAME SUFFIX  RESZIPCODE       RESADDRESS1         RESADDRESS2  \
# 1156230        NaN    NaN       48103     603 DUNCAN ST  ANN ARBOR MI 48103
# 1156895       RUTH    NaN       48103  412 WESTWOOD AVE  ANN ARBOR MI 48103
# 1156940        NaN    NaN       48103    1011 DUNCAN ST  ANN ARBOR MI 48103
# 1157122      BRUCE    NaN       48103  411 WESTWOOD AVE  ANN ARBOR MI 48103
# 1157124         JO    NaN       48103  411 WESTWOOD AVE  ANN ARBOR MI 48103
#
# ...

# %%
for id in bruce_reps.VOTERID:
    vdf.loc[vdf.voter_id == id, 'party'] = 'R'
pd.unique(vdf.party)
# Out:
# array(['X', 'D', 'R'], dtype=object)
