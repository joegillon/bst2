# %%
import os
os.chdir('c:/bench/bst/data')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
edf=pd.read_csv('mi/elections.csv')
edf.head()
# Out:
#          id        date            description  birth_yr  score
# 0  31000153  2017-11-07  NOVEMBER CONSOLIDATED      1999      5
# 1  31000152  2017-08-08    AUGUST CONSOLIDATED      1999      5
# 2  31000151  2017-05-02       MAY CONSOLIDATED      1999      5
# 3  31000053  2016-11-08          STATE GENERAL      1998      1
# 4  31000052  2016-08-02          STATE PRIMARY      1998      4

# %%
cols = edf.date[0:15]

# %%
vdf=pd.read_csv('voters/Bruce_St_voters.csv')
vdf.head()
# Out:
#   last_name first_name middle_name name_suffix  birth_year gender  \
# 0     RABLE    ZACHARY      ANDREW         NaN        1988      M
# 1     BIGGS       CURT       ELLIS         NaN        1965      M
# 2     FLYNN     DENISE           M         NaN        1957      F
# 3  KIRCHNER     AUDREY         NaN         NaN        1945      F
# 4     MAZUR       LORI        ANNE         NaN        1959      F
#
#        street_address       city  zipcode  county  ...  2011-09-13  \
# 0  2015  MILLER AVE    ANN ARBOR    48103      81  ...           N
# 1  1877  MILLER AVE    ANN ARBOR    48103      81  ...           N
# 2  2133  MILLER AVE    ANN ARBOR    48103      81  ...           N
# 3  2011  MILLER AVE    ANN ARBOR    48103      81  ...           N
# 4  2035  MILLER AVE    ANN ARBOR    48103      81  ...           N
#
#    2011-08-02  2011-05-03  2011-02-22  2010-11-02  2010-09-14  2010-08-03  \
# 0           N           N           N           Y           X           X
# 1           N           N           N           N           N           N
# 2           N           N           N           Y           N           N
# 3           N           N           N           Y           N           Y
# 4           N           N           N           N           N           N
#
#   2010-05-04 2010-02-23 2010-02-08
# 0          X          X          X
# 1          N          N          N
# 2          N          N          N
# 3          N          N          N
# 4          N          N          N
#
# [5 rows x 64 columns]

# %%
mdf=vdf.loc[vdf.gender=='M', cols]
mdf.head()
# Out:
#    2017-11-07 2017-08-08 2017-05-02 2016-11-08 2016-08-02 2016-05-03  \
# 0           Y          Y          N          N          N          N
# 1           N          N          N          Y          N          N
# 5           N          N          N          N          N          N
# 7           N          Y          N          Y          N          N
# 11          N          N          N          N          N          N
#
#    2016-03-08 2015-11-03 2015-08-04 2015-05-05 2015-02-24 2014-11-04  \
# 0           Y          N          N          N          N          Y
# 1           Y          N          N          N          N          Y
# 5           N          N          N          N          N          N
# 7           Y          N          Y          N          N          Y
# 11          N          N          N          N          N          N
#
#    2014-08-05 2014-05-06 2014-02-25
# 0           N          N          N
# 1           N          N          N
# 5           N          N          N
# 7           Y          N          N
# 11          N          N          N

# %%
fdf=vdf.loc[vdf.gender=='F', cols]
fdf.head()
# Out:
#   2017-11-07 2017-08-08 2017-05-02 2016-11-08 2016-08-02 2016-05-03  \
# 2          N          N          N          Y          Y          N
# 3          Y          Y          N          Y          N          N
# 4          N          N          N          Y          N          N
# 6          N          N          N          N          N          N
# 8          N          N          N          Y          N          N
#
#   2016-03-08 2015-11-03 2015-08-04 2015-05-05 2015-02-24 2014-11-04  \
# 2          N          Y          N          N          N          Y
# 3          Y          N          Y          Y          N          Y
# 4          Y          N          N          N          N          Y
# 6          N          N          N          N          N          N
# 8          Y          N          N          N          N          Y
#
#   2014-08-05 2014-05-06 2014-02-25
# 2          N          N          N
# 3          Y          N          N
# 4          N          N          N
# 6          N          N          N
# 8          Y          N          N
