# %%
import os
os.chdir('c:/bench/reps/michigan/data')

# %%
import pandas as pd

# %%
df=pd.read_csv('voters.csv')
df.head()
# Out:
#    last_name first_name middle_name name_suffix  date_of_birth  birth_year  \
# 0  SCHOUWINK      KAREN           M         NaN            NaN        1959
# 1   GATEWOOD   DAVONTAE      EUGENE         NaN            NaN        1999
# 2     GAITAN    DERRICK      MIKEAL         NaN            NaN        1993
# 3   GIDDINGS     JOSHUA        JOHN         NaN            NaN        1974
# 4      IRVIN     YVONNE           N         NaN            NaN        1960
#
#   gender  ethnicity             street_address              city  ...  ward  \
# 0      F        NaN     1843  FAWNBROOKE RUN             ALLEGAN  ...     0
# 1      M        NaN      9459 E PICKWICK CIR              TAYLOR  ...     0
# 2      M        NaN  1779  LIBERTY DR  APT 202    MOUNT PLEASANT  ...     0
# 3      M        NaN         4105  MEADOW WAY    BLOOMFIELD HILLS  ...     0
# 4      F        NaN      15744  PINEHURST ST             DETROIT  ...     2
#
# ...

# %%
b=df[df['street_address'].str.contains('BRUCE')]

# %%
b=b[b['city']=='ANN ARBOR']

# %%
b.head()
# Out:
#         last_name first_name middle_name name_suffix  date_of_birth  \
# 1084886  HORROCKS      DAVID        ALAN         NaN            NaN
# 1084887  HORROCKS     MARLEE        JANE         NaN            NaN
# 1085126   HETTMER      DAVID       JAMES         NaN            NaN
# 1087080     HEADY    DOUGLAS      JULIAN         NaN            NaN
# 1087107      HITT     ARLENE      LOUISE         NaN            NaN
#
#          birth_year gender  ethnicity   street_address       city  ...  ward  \
# 1084886        1946      M        NaN  915  BRUCE ST    ANN ARBOR  ...     5
# 1084887        1950      F        NaN  915  BRUCE ST    ANN ARBOR  ...     5
# 1085126        1962      M        NaN  929  BRUCE ST    ANN ARBOR  ...     5
# 1087080        1957      M        NaN  817  BRUCE ST    ANN ARBOR  ...     5
# 1087107        1925      F        NaN  908  BRUCE ST    ANN ARBOR  ...     5
#
#          precinct  congress  state_senate state_house  voter_id  reg_date  \
# ...

# %%
aa=df[df['city']=='ANN ARBOR']
aa.head()
# Out:
#      last_name first_name middle_name name_suffix  date_of_birth  birth_year  \
# 57   ALBERTINI    JEFFREY           M         NaN            NaN        1984
# 60     FEURINO      LOUIS     WILLIAM         NaN            NaN        1979
# 163     DAWSON       JOHN     FORREST          JR            NaN        1949
# 184       GANZ     LAUREN         NaN         NaN            NaN        1962
# 869       GANN     JOSHUA    LAWRENCE         NaN            NaN        1988
#
#     gender  ethnicity                 street_address       city  ...  ward  \
# 57       M        NaN            205  HIGHLAKE AVE    ANN ARBOR  ...     5
# 60       M        NaN            3026  CLOVERLY LN    ANN ARBOR  ...     3
# 163      M        NaN            525  ELIZABETH ST    ANN ARBOR  ...     1
# 184      F        NaN              244  MURRAY AVE    ANN ARBOR  ...     5
# 869      M        NaN  1015  RABBIT RUN CIR  APT 103  ANN ARBOR  ...     0
#
# ...

# %%
b=aa[aa['street_address'].str.contains('BRUCE')]
b
# Out:
#               last_name first_name   middle_name name_suffix  birth_year  \
# 1084886        HORROCKS      DAVID          ALAN         NaN        1946
# 1084887        HORROCKS     MARLEE          JANE         NaN        1950
# 1085126         HETTMER      DAVID         JAMES         NaN        1962
# 1087080           HEADY    DOUGLAS        JULIAN         NaN        1957
# 1087107            HITT     ARLENE        LOUISE         NaN        1925
# 1087555           FOUTY        DON        NORMAN         NaN        1952
# 1087556           FOUTY      NORMA          JEAN         NaN        1955
# 1087926        HOLBROOK      JANET           KAY         NaN        1945
# 1089655        SWANBROW     DENISE          ANNE         NaN        1956
# 1090735    SCHEEL-AYERS    BARBARA          ANNE         NaN        1950
# 1090736    SCHEEL-AYERS    GREGORY   CHRISTOPHER         NaN        1952
# 1092188        PETERSEN    ROBERTA          JEAN         NaN        1926
# ...

# %%
aa.to_csv('c:/bench/bst/data/aa.csv', header=True, index=False)

# %%
aa.drop(['date_of_birth', 'ethnicity'], axis=1, inplace=True)
# Out:
# C:\Python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
os.getcwd()
# Out:
# 'c:\\bench\\reps\\michigan\\data'

# %%
my=pd.read_csv('c:/bench/bst/data/my_voters.csv')

# %%
my.head()
# Out:
#          FRISON      IAN       MICHAEL Unnamed: 3  1999  M  \
# 0  ELISCHBERGER   HOLGER  BERND-HARALD        NaN  1969  M
# 1       RAYMOND   JOSHUA         ALLEN        NaN  1989  M
# 2         CAREY     ERIC       STEPHEN        NaN  1987  M
# 3     LEVASSEUR  KATHRYN          MARY        NaN  1990  F
# 4       YUPONCO      KAI          REMO        NaN  1995  M
#
#   1860  FRANKLIN ST    ANN ARBOR  48103  81  ...  012  12  18  55  33235406  \
# 0    601  DUNCAN ST    ANN ARBOR  48103  81  ...    9  12  18  55  33347237
# 1   1659  FULMER ST    ANN ARBOR  48103  81  ...   12  12  18  55  33472093
# 2   2109  ARLENE ST    ANN ARBOR  48103  81  ...    9  12  18  55  33254664
# 3   2107  ARLENE ST    ANN ARBOR  48103  81  ...    9  12  18  55  33543200
# 4   1014  DUNCAN ST    ANN ARBOR  48103  81  ...    9  12  18  55  33544700
#
#    4052017  A  N Unnamed: 20  Garden_Homes
# 0  5312017  A  N         NaN      Bruce_St
# 1  7272017  A  N         NaN  Garden_Homes
# ...

# %%
my.columns
# Out:
# Index(['FRISON', 'IAN', 'MICHAEL', 'Unnamed: 3', '1999', 'M',
#        '1860  FRANKLIN ST  ', 'ANN ARBOR', '48103', '81', '3000', '5', '012',
#        '12', '18', '55', '33235406', '4052017', 'A', 'N', 'Unnamed: 20',
#        'Garden_Homes'],
#       dtype='object')

# %%
bruce = my[my['']]
